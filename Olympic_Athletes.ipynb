# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
olympics_csv = "olympic_data.csv"

# Read the City and Ride Data
olympics = pd.read_csv(olympics_csv)
olympics.head()
# Out:
#        ID                Name Sex   Age  Height  Weight         Team  NOC  \
# 0  107506   Hermann Schreiber   M  26.0     NaN     NaN  Switzerland  SUI
# 1      20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 2      20  Kjetil Andr Aamodt   M  26.0   176.0    85.0       Norway  NOR
# 3      20  Kjetil Andr Aamodt   M  30.0   176.0    85.0       Norway  NOR
# 4     634         Paul Accola   M  20.0   176.0    82.0  Switzerland  SUI
#
#          Games  Year  Season            City          Sport  \
# 0  1936 Summer  1936  Summer          Berlin    Aeronautics
# 1  1994 Winter  1994  Winter     Lillehammer  Alpine Skiing
# 2  1998 Winter  1998  Winter          Nagano  Alpine Skiing
# 3  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 4  1988 Winter  1988  Winter         Calgary  Alpine Skiing
#
#                            Event   Medal
# 0  Aeronautics Mixed Aeronautics    Gold
# 1   Alpine Skiing Men's Combined  Silver
# ...

# %%
cleaned_medal_df = olympics.dropna(how="any")
cleaned_medal_df.head()
# Out:
#        ID                Name Sex   Age  Height  Weight         Team  NOC  \
# 1      20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 3      20  Kjetil Andr Aamodt   M  30.0   176.0    85.0       Norway  NOR
# 4     634         Paul Accola   M  20.0   176.0    82.0  Switzerland  SUI
# 13   2792         mile Allais   M  23.0   168.0    68.0       France  FRA
# 96  23517       James Couttet   M  26.0   168.0    67.0       France  FRA
#
#           Games  Year  Season                    City          Sport  \
# 1   1994 Winter  1994  Winter             Lillehammer  Alpine Skiing
# 3   2002 Winter  2002  Winter          Salt Lake City  Alpine Skiing
# 4   1988 Winter  1988  Winter                 Calgary  Alpine Skiing
# 13  1936 Winter  1936  Winter  Garmisch-Partenkirchen  Alpine Skiing
# 96  1948 Winter  1948  Winter            Sankt Moritz  Alpine Skiing
#
#                            Event   Medal
# 1   Alpine Skiing Men's Combined  Silver
# ...

# %%
top_olympian = olympics.groupby(["Name", "Medal"])["Sport"].count().reset_index().sort_values(by = "Sport",ascending = False)
top_olympian = top_olympian.drop_duplicates(subset=['Medal'],keep='first')
top_olympian.columns=[['Athlete','Medal','Count']]
top_olympian
# Out:
#                          Athlete   Medal Count
# 21615    Michael Fred Phelps, II    Gold    23
# 27949  Shirley Frances Babashoff  Silver     6
# 11851   Heikki Ilmari Savolainen  Bronze     6

# %%
top_gymnist = cleaned_medal_df.loc[:,["ID", "Name", "Age", "Sex", "Height", "Weight", "Team", "Games", "Year", "Sport", "Medal"]]
top_gymnist.head()
# Out:
#        ID                Name   Age Sex  Height  Weight         Team  \
# 1      20  Kjetil Andr Aamodt  22.0   M   176.0    85.0       Norway
# 3      20  Kjetil Andr Aamodt  30.0   M   176.0    85.0       Norway
# 4     634         Paul Accola  20.0   M   176.0    82.0  Switzerland
# 13   2792         mile Allais  23.0   M   168.0    68.0       France
# 96  23517       James Couttet  26.0   M   168.0    67.0       France
#
#           Games  Year          Sport   Medal
# 1   1994 Winter  1994  Alpine Skiing  Silver
# 3   2002 Winter  2002  Alpine Skiing    Gold
# 4   1988 Winter  1988  Alpine Skiing  Bronze
# 13  1936 Winter  1936  Alpine Skiing  Bronze
# 96  1948 Winter  1948  Alpine Skiing  Bronze

# %%
top_five = top_gymnist[((top_gymnist["Sport"]=="Gymnastics") & 
                        (top_gymnist["Sex"]=="M") & 
                        (top_gymnist["Medal"]=="Gold"))]
top_five.head()
# Out:
#            ID                          Name   Age Sex  Height  Weight  \
# 131683   1483               Nobuyuki Aihara  25.0   M   154.0    53.0
# 131701   4198  Nikolay Yefimovich Andrianov  19.0   M   166.0    60.0
# 131702   4198  Nikolay Yefimovich Andrianov  23.0   M   166.0    60.0
# 131866  15676                Roland Brckner  24.0   M   172.0    65.0
# 132415  57998                    Sawao Kato  22.0   M   163.0    59.0
#
#                 Team        Games  Year       Sport Medal
# 131683         Japan  1960 Summer  1960  Gymnastics  Gold
# 131701  Soviet Union  1972 Summer  1972  Gymnastics  Gold
# 131702  Soviet Union  1976 Summer  1976  Gymnastics  Gold
# 131866  East Germany  1980 Summer  1980  Gymnastics  Gold
# 132415         Japan  1968 Summer  1968  Gymnastics  Gold

# %%
top_olympian = top_five.groupby(["ID","Team","Name","Height","Weight"]).count()["Medal"].sort_values(ascending = False)
top_olympian.head()
# Out:
# ID      Team          Name                           Height  Weight
# 57998   Japan         Sawao Kato                     163.0   59.0      8
# 4198    Soviet Union  Nikolay Yefimovich Andrianov   166.0   60.0      7
# 109161  Soviet Union  Borys Anfiyanovych Shakhlin    171.0   71.0      7
# 109416  Unified Team  Vitaly Venediktovich Shcherbo  169.0   68.0      6
# 84381   Japan         Akinori Nakayama               163.0   59.0      6
# Name: Medal, dtype: int64

# %%
olympian_summary = pd.DataFrame(top_olympian)
olympian_summary.head()
# Out:
#                                                                  Medal
# ID     Team         Name                          Height Weight
# 57998  Japan        Sawao Kato                    163.0  59.0        8
# 4198   Soviet Union Nikolay Yefimovich Andrianov  166.0  60.0        7
# 109161 Soviet Union Borys Anfiyanovych Shakhlin   171.0  71.0        7
# 109416 Unified Team Vitaly Venediktovich Shcherbo 169.0  68.0        6
# 84381  Japan        Akinori Nakayama              163.0  59.0        6
